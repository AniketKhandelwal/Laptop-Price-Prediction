# %%
import pandas as pd
import numpy as np
import kaggle as kg
import os

# %%
os.environ["USERNAME"]="aniketkhandelwal07"
os.environ["KEY"]="f85936e7918a5835c805033a6cd2bbce"

# %%
kg.api.authenticate()

# %%
kg.api.dataset_download_files(dataset="ehtishamsadiq/uncleaned-laptop-price-dataset",path="./dataset",unzip=True)
# Out:
# Dataset URL: https://www.kaggle.com/datasets/ehtishamsadiq/uncleaned-laptop-price-dataset

# %%
data=pd.read_csv("dataset/laptopData.csv")

# %%
data
# Out:
#       Unnamed: 0 Company            TypeName Inches  \
# 0            0.0   Apple           Ultrabook   13.3
# 1            1.0   Apple           Ultrabook   13.3
# 2            2.0      HP            Notebook   15.6
# 3            3.0   Apple           Ultrabook   15.4
# 4            4.0   Apple           Ultrabook   13.3
# ...          ...     ...                 ...    ...
# 1298      1298.0  Lenovo  2 in 1 Convertible     14
# 1299      1299.0  Lenovo  2 in 1 Convertible   13.3
# 1300      1300.0  Lenovo            Notebook     14
# 1301      1301.0      HP            Notebook   15.6
# 1302      1302.0    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Company', 'TypeName', 'Inches', 'ScreenResolution',
#        'Cpu', 'Ram', 'Memory', 'Gpu', 'OpSys', 'Weight', 'Price'],
#       dtype='object')

# %%
data.drop(labels=data.columns[0],axis=1,inplace=True)

# %%
pd.DataFrame(data[data.columns[0]].unique())
# Out:
#             0
# 0       Apple
# 1          HP
# 2        Acer
# 3        Asus
# 4        Dell
# 5      Lenovo
# 6         NaN
# 7       Chuwi
# 8         MSI
# 9   Microsoft
# 10    Toshiba
# 11     Huawei
# 12     Xiaomi
# 13       Vero
# 14      Razer
# 15   Mediacom
# 16    Samsung
# 17     Google
# 18    Fujitsu
# 19         LG

# %%
data.isna().sum()
# Out:
# Company             30
# TypeName            30
# Inches              30
# ScreenResolution    30
# Cpu                 30
# Ram                 30
# Memory              30
# Gpu                 30
# OpSys               30
# Weight              30
# Price               30
# dtype: int64

# %%
data.dropna(axis=0,inplace=True)

# %%
data
# Out:
#      Company            TypeName Inches  \
# 0      Apple           Ultrabook   13.3
# 1      Apple           Ultrabook   13.3
# 2         HP            Notebook   15.6
# 3      Apple           Ultrabook   15.4
# 4      Apple           Ultrabook   13.3
# ...      ...                 ...    ...
# 1298  Lenovo  2 in 1 Convertible     14
# 1299  Lenovo  2 in 1 Convertible   13.3
# 1300  Lenovo            Notebook     14
# 1301      HP            Notebook   15.6
# 1302    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
def label_encode_column(column_name):
    data[column_name].unique()

    d=dict()
    for value in data[column_name].unique():
        d[value]=data[data[column_name]==value][data.columns[-1]].mean()
                #data[column_name]==value ---> Boolean Mask function, If we put this in data function then it will pull out the company names that are unique ex: Apple,HP,Dell
                #data[column_name[-1]].mean ---> We have taken the last column that is price and took the mean for that particular company.

    input_target_df = pd.DataFrame(data={column_name:d.keys(),"Mean price":d.values()})
    input_target_df.sort_values(by="Mean price",inplace=True)
    input_target_df.reset_index(inplace=True,drop=True)

    data[column_name] = data[column_name].replace(to_replace=list(input_target_df[column_name]),value=list(input_target_df.index)).infer_objects(copy=False)

# %%
a=[data.columns[0],data.columns[1],data.columns[3],data.columns[7]]

for i in a:
     label_encode_column(i)
data
# Out:
# /tmp/ipykernel_1124/1459030301.py:14: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data[column_name] = data[column_name].replace(to_replace=list(input_target_df[column_name]),value=list(input_target_df.index)).infer_objects(copy=False)
#       Company  TypeName Inches  ScreenResolution  \
# 0          13         3   13.3                26
# 1          13         3   13.3                13
# 2           5         1   15.6                15
# 3          13         3   15.4                36
# 4          13         3   13.3                26
# ...       ...       ...    ...               ...
# 1298        6         2     14                16
# 1299        6         2   13.3                22
# 1300        6         1     14                 4
# ...

# %%
data['Ram'] = data['Ram'].str.replace('GB','').astype(int)
#data.columns[5] = data.columns[5].str.replace('GB','').astype(int)
data
# Out:
#       Company  TypeName Inches  ScreenResolution  \
# 0          13         3   13.3                26
# 1          13         3   13.3                13
# 2           5         1   15.6                15
# 3          13         3   15.4                36
# 4          13         3   13.3                26
# ...       ...       ...    ...               ...
# 1298        6         2     14                16
# 1299        6         2   13.3                22
# 1300        6         1     14                 4
# 1301        5         1   15.6                 4
# 1302        7         1   15.6                 4
#
#                                        Cpu  Ram               Memory  Gpu  \
# 0                     Intel Core i5 2.3GHz    8            128GB SSD   80
# 1                     Intel Core i5 1.8GHz    8  128GB Flash Storage   45
# 2               Intel Core i5 7200U 2.5GHz    8            256GB SSD   54
# 3                     Intel Core i7 2.7GHz   16            512GB SSD   95
# ...
